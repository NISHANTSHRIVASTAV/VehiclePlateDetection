# %% [markdown]
# # Vehicle Plate Detection Inference Engine

# %% [markdown]
# ## Prediction Results
#
# Total Test Images - 63
#
# ### On CPU
#
# Inference Time for each image - 0.140625
# Batch wise Prediction Time :-  {'batch_0': 4.4845263957977295, 'batch_1': 4.359519004821777, 'batch_2': 0.29688358306884766}
#
# ### On GPUs
#
# Inference Time for each image - 0.015690
# Batch wise Prediction Time :-  {'batch_0': 1.7811949253082275, 'batch_1': 0.45837974548339844, 'batch_2': 0.031238794326782227}

# %%
from vision.ssd.vgg_ssd import create_vgg_ssd, create_vgg_ssd_predictor
from vision.ssd.mobilenetv1_ssd import create_mobilenetv1_ssd, create_mobilenetv1_ssd_predictor
from vision.ssd.mobilenetv1_ssd_lite import create_mobilenetv1_ssd_lite, create_mobilenetv1_ssd_lite_predictor
from vision.ssd.squeezenet_ssd_lite import create_squeezenet_ssd_lite, create_squeezenet_ssd_lite_predictor
from vision.ssd.mobilenet_v2_ssd_lite import create_mobilenetv2_ssd_lite, create_mobilenetv2_ssd_lite_predictor
from vision.utils.misc import Timer
import logging
import cv2

# %%
MODEL_FILE_PATH = 'models\\custom_trained\\mb1-ssd-Epoch-211-Loss-2.275852680206299.pth'
LABEL_FILE_PATH = 'labels\\labels.txt'
LOG_FILE_PATH = 'logs\\vehicle_plate_detector_logger.log'
TEST_FILE_PATH = 'dataset\\VOC2007\\ImageSets\\Main\\test.txt'
RUNTIME_DEVICE_TYPE = 'cpu'

# %%
logging.basicConfig(filename=LOG_FILE_PATH, filemode='a', level=logging.INFO,\
                    format='%(asctime)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')
logging.info('Vehicle Plate Inference Engine')

# %%
class VehiclePlateDetector():

    def __init__(self, net_type, model_path, label_path, device):
        
        try:
            self.net_type = net_type
            self.model_path = model_path
            self.label_path = label_path
            self.class_names = [name.strip() for name in open(self.label_path).readlines()]
            self.timer = Timer()

            if self.net_type == 'vgg16-ssd':
                self.net = create_vgg_ssd(len(self.class_names ), is_test=True, device=device)
            elif self.net_type == 'mb1-ssd':
                self.net = create_mobilenetv1_ssd(len(self.class_names ), is_test=True, device=device)
            elif self.net_type == 'mb1-ssd-lite':
                self.net = create_mobilenetv1_ssd_lite(len(self.class_names ), is_test=True, device=device)
            elif self.net_type == 'mb2-ssd-lite':
                self.net = create_mobilenetv2_ssd_lite(len(self.class_names ), is_test=True, device=device)
            elif self.net_type == 'sq-ssd-lite':
                self.net = create_squeezenet_ssd_lite(len(self.class_names ), is_test=True, device=device)
            else:
                logging.info(f"Init from base net {args.base_net}")
                print("The net type is wrong. It should be one of vgg16-ssd, mb1-ssd and mb1-ssd-lite.")

            self.net.load(self.model_path)

            if self.net_type == 'vgg16-ssd':
                self.predictor = create_vgg_ssd_predictor(self.net, candidate_size=200, device=device)
            elif self.net_type == 'mb1-ssd':
                self.predictor = create_mobilenetv1_ssd_predictor(self.net, candidate_size=200, device=device)
            elif self.net_type == 'mb1-ssd-lite':
                self.predictor = create_mobilenetv1_ssd_lite_predictor(self.net, candidate_size=200, device=device)
            elif self.net_type == 'mb2-ssd-lite':
                self.predictor = create_mobilenetv2_ssd_lite_predictor(self.net, candidate_size=200, device=device)
            elif self.net_type == 'sq-ssd-lite':
                self.predictor = create_squeezenet_ssd_lite_predictor(self.net, candidate_size=200, device=device)
            else:
                self.predictor = create_vgg_ssd_predictor(self.net, candidate_size=200, device=device)
        except Exception as e:
            logging.error("Caught an exception in VehiclePlateDetector constructor", exc_info=True)
            print("Caught an exception in VehiclePlateDetector constructor", e)

    def detect_objects(self, image):
        
        try:
            self.timer.start("Load Image")
            orig_image = cv2.imread(image)
            load_end_time = self.timer.end("Load Image")
            print("Load Image: {:4f} seconds.".format(load_end_time))
            logging.info(f"Load Image seconds {load_end_time}")

            self.timer.start("Predict")
            boxes, labels, probs = self.predictor.predict(orig_image, 10, 0.4)
            predict_end_time = self.timer.end("Predict")
            print("Prediction: {:4f} seconds.".format(predict_end_time))
            logging.info(f"Prediction seconds {predict_end_time}")
            print("---------------------------------------------------------------------")

            for i in range(boxes.size(0)):
                box = boxes[i, :]
                c1 = int(box[0].numpy())
                c2 = int(box[1].numpy())
                c3 = int(box[2].numpy())
                c4 = int(box[3].numpy())
                cv2.rectangle(orig_image, (c1, c2), (c3, c4), (255, 255, 0), 4)
                label = f"{self.class_names [labels[i]]}: {probs[i]:.2f}"
                print("Vehicle Plate Detector Prediction ", label)
                logging.info(f"Vehicle Plate Detector Prediction  {label}")
                cv2.putText(orig_image, label, (c1-40, c2), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2)
                file_save_path = 'results\\output_' + str(count) + '.jpg' 
                cv2.imwrite(file_save_path, orig_image)
            return predict_end_time
        except Exception as e:
            logging.error("Caught an exception in detect_objects", exc_info=True)
            print("Caught an exception in detect_objects", e)

# %%
if __name__ == '__main__':
    
    try:
        detector = VehiclePlateDetector('mb1-ssd', MODEL_FILE_PATH, LABEL_FILE_PATH, RUNTIME_DEVICE_TYPE)
        file1 = open(TEST_FILE_PATH, 'r')
        lines = file1.readlines()
        count = 1
        batch_count = 0
        batch_inference_time = 0
        batch_inference_time_container = {}

        for file_name in range(len(lines)):
            file_path = 'dataset\\VOC2007\\JPEGImages\\' + str(lines[file_name].strip('\n')) + '.jpg'
            print("---------------------------------------------------------------------")
            print("Process image - ", count)
            logging.info(f"Process image {count}")
            predict_end_time = detector.detect_objects(file_path)
            if count % 30 == 0 or count == len(lines):
                batch_no = "batch_" + str(batch_count)
                batch_inference_time_container[batch_no] = batch_inference_time
                batch_inference_time = 0
                batch_count += 1
            else:
                batch_inference_time += predict_end_time

            count += 1

        print("Batch wise Prediction Time :- ", batch_inference_time_container)
        logging.info(f"Batch wise Prediction Time :-  {batch_inference_time_container}")
        print("------------------------------------------------------------------------")
    except Exception as e:
        logging.error("Caught an exception in main function", exc_info=True)
        print("Caught an exception in main function", e)
# Out:
# ---------------------------------------------------------------------
# Process image -  1
# Load Image: 0.010001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.23250341415405273
# Prediction: 0.239504 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.58
# ---------------------------------------------------------------------
# Process image -  2
# Load Image: 0.022046 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14062190055847168
# Prediction: 0.140622 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  3
# Load Image: 0.017721 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1186833381652832
# Prediction: 0.123683 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  4
# Load Image: 0.015623 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13966703414916992
# Prediction: 0.139667 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  5
# Load Image: 0.015622 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1250004768371582
# Prediction: 0.125000 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.89
# ---------------------------------------------------------------------
# Process image -  6
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14905786514282227
# Prediction: 0.150060 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.51
# ---------------------------------------------------------------------
# Process image -  7
# Load Image: 0.001998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13075804710388184
# Prediction: 0.136763 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  8
# Load Image: 0.001000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.15253496170043945
# Prediction: 0.157536 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  9
# Load Image: 0.015625 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12500357627868652
# Prediction: 0.125004 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  10
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1420307159423828
# Prediction: 0.142031 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  11
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.132002592086792
# Prediction: 0.142514 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  12
# Load Image: 0.001998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14200758934020996
# Prediction: 0.148008 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  13
# Load Image: 0.002999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13007116317749023
# Prediction: 0.137074 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.98
# ---------------------------------------------------------------------
# Process image -  14
# Load Image: 0.051003 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12268805503845215
# Prediction: 0.128688 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  15
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14220094680786133
# Prediction: 0.158810 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.46
# ---------------------------------------------------------------------
# Process image -  16
# Load Image: 0.003000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1300060749053955
# Prediction: 0.137007 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  17
# Load Image: 0.001000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13500690460205078
# Prediction: 0.141008 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  18
# Load Image: 0.001001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13386845588684082
# Prediction: 0.135916 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  19
# Load Image: 0.000998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13500547409057617
# Prediction: 0.141008 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  20
# Load Image: 0.001001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13100910186767578
# Prediction: 0.137007 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.83
# ---------------------------------------------------------------------
# Process image -  21
# Load Image: 0.005000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13800859451293945
# Prediction: 0.145010 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.86
# ---------------------------------------------------------------------
# Process image -  22
# Load Image: 0.002001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.11578893661499023
# Prediction: 0.136414 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.64
# ---------------------------------------------------------------------
# Process image -  23
# Load Image: 0.005889 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13100457191467285
# Prediction: 0.137009 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.50
# ---------------------------------------------------------------------
# Process image -  24
# Load Image: 0.002001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13584113121032715
# Prediction: 0.141842 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  25
# Load Image: 0.002002 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1430060863494873
# Prediction: 0.149006 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  26
# Load Image: 0.017003 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1300051212310791
# Prediction: 0.136005 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  27
# Load Image: 0.002002 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12900614738464355
# Prediction: 0.137008 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  28
# Load Image: 0.002002 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13418936729431152
# Prediction: 0.141191 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  29
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13782835006713867
# Prediction: 0.139831 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.96
# ---------------------------------------------------------------------
# Process image -  30
# Load Image: 0.000999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12791109085083008
# Prediction: 0.132911 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  31
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14526057243347168
# Prediction: 0.145261 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  32
# Load Image: 0.001998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12667226791381836
# Prediction: 0.132675 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.64
# ---------------------------------------------------------------------
# Process image -  33
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1363215446472168
# Prediction: 0.152924 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  34
# Load Image: 0.001999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1400165557861328
# Prediction: 0.147010 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  35
# Load Image: 0.003002 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14101004600524902
# Prediction: 0.148009 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.89
# ---------------------------------------------------------------------
# Process image -  36
# Load Image: 0.001999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13368725776672363
# Prediction: 0.138691 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  37
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1418917179107666
# Prediction: 0.142891 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  38
# Load Image: 0.004000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13789987564086914
# Prediction: 0.143899 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  39
# Load Image: 0.001998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14200639724731445
# Prediction: 0.148008 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  40
# Load Image: 0.000997 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1280045509338379
# Prediction: 0.134057 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.94
# ---------------------------------------------------------------------
# Process image -  41
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14061832427978516
# Prediction: 0.140618 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.89
# ---------------------------------------------------------------------
# Process image -  42
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14838767051696777
# Prediction: 0.149398 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  43
# Load Image: 0.021034 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14646577835083008
# Prediction: 0.147467 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.85
# ---------------------------------------------------------------------
# Process image -  44
# Load Image: 0.001997 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1400129795074463
# Prediction: 0.146011 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  45
# Load Image: 0.002000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.14300274848937988
# Prediction: 0.149010 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  46
# Load Image: 0.000999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12700557708740234
# Prediction: 0.133013 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  47
# Load Image: 0.000998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13231682777404785
# Prediction: 0.138317 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  48
# Load Image: 0.001000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12104153633117676
# Prediction: 0.126042 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  49
# Load Image: 0.015625 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13589048385620117
# Prediction: 0.137888 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.97
# ---------------------------------------------------------------------
# Process image -  50
# Load Image: 0.014001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12900662422180176
# Prediction: 0.136010 seconds.
# ---------------------------------------------------------------------
# ---------------------------------------------------------------------
# Process image -  51
# Load Image: 0.002998 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13500618934631348
# Prediction: 0.142010 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.95
# ---------------------------------------------------------------------
# Process image -  52
# Load Image: 0.003000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1292269229888916
# Prediction: 0.136230 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  53
# Load Image: 0.002999 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13512587547302246
# Prediction: 0.142129 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.97
# ---------------------------------------------------------------------
# Process image -  54
# Load Image: 0.003005 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12154269218444824
# Prediction: 0.126540 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.95
# ---------------------------------------------------------------------
# Process image -  55
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12626218795776367
# Prediction: 0.141852 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  56
# Load Image: 0.015621 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12396049499511719
# Prediction: 0.123960 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.89
# ---------------------------------------------------------------------
# Process image -  57
# Load Image: 0.015624 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.11694025993347168
# Prediction: 0.124055 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.90
# ---------------------------------------------------------------------
# Process image -  58
# Load Image: 0.000000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1434190273284912
# Prediction: 0.144419 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.98
# ---------------------------------------------------------------------
# Process image -  59
# Load Image: 0.003001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1316378116607666
# Prediction: 0.134667 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.99
# ---------------------------------------------------------------------
# Process image -  60
# Load Image: 0.001001 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13200879096984863
# Prediction: 0.139008 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# ---------------------------------------------------------------------
# Process image -  61
# Load Image: 0.013004 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.12041020393371582
# Prediction: 0.126409 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.52
# ---------------------------------------------------------------------
# Process image -  62
# Load Image: 0.015624 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.1394033432006836
# Prediction: 0.141405 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 0.64
# ---------------------------------------------------------------------
# Process image -  63
# Load Image: 0.003000 seconds.
# -----------------------------------------------------------
# Device cpu
# -----------------------------------------------------------
# Inference time:  0.13121867179870605
# Prediction: 0.137225 seconds.
# ---------------------------------------------------------------------
# Vehicle Plate Detector Prediction  license_plate: 1.00
# Batch wise Prediction Time :-  {'batch_0': 4.1502251625061035, 'batch_1': 4.053061008453369, 'batch_2': 0.26781392097473145}
# ------------------------------------------------------------------------
